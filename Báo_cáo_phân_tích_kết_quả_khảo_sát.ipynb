# %% [markdown]
# <a href="https://colab.research.google.com/github/Lhn91/-HCMUT--Data_Analysis_Survey_SEMESTER241/blob/main/B%C3%A1o_c%C3%A1o_ph%C3%A2n_t%C3%ADch_k%E1%BA%BFt_qu%E1%BA%A3_kh%E1%BA%A3o_s%C3%A1t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BÀI BÁO CÁO PHÂN TÍCH KHẢO SÁT**

# %%
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt
from IPython.display import HTML
df = pd.read_excel('sample_data/data.xlsx')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2784 entries, 0 to 2783
# Data columns (total 80 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   STT                2783 non-null   float64
#  1   Tên khảo sát       2783 non-null   object
#  2   MSSV               2783 non-null   object
#  3   Họ và tên          2783 non-null   object
#  4   Mã ngành           2783 non-null   float64
#  5   Tên ngành          2783 non-null   object
#  6   Bậc                2783 non-null   object
#  7   Hệ                 2783 non-null   object
#  8   Chương trình       2783 non-null   object
#  9   Nội dung khảo sát  2784 non-null   object
#  10  Unnamed: 10        2784 non-null   object
#  11  Unnamed: 11        2784 non-null   object
#  12  Unnamed: 12        1926 non-null   object
#  13  Unnamed: 13        1921 non-null   object
#  14  Unnamed: 14        1925 non-null   object
#  15  Unnamed: 15        1910 non-null   object
# ...

# %% [markdown]
# # **Chuẩn bị dữ liệu**

# %%
columns_to_checkA = ["Nội dung khảo sát", "Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16"]
new_nameA = {"Nội dung khảo sát": "A1.1", "Unnamed: 10": "A1.2", "Unnamed: 11": "A1.3", "Unnamed: 12": "A2.4", "Unnamed: 13": "A2.5", "Unnamed: 14": "A2.6", "Unnamed: 15": "A2.7", "Unnamed: 16": "A2.8"}

columns_to_checkB = ["Unnamed: 17", "Unnamed: 19", "Unnamed: 21", "Unnamed: 23", "Unnamed: 25", "Unnamed: 27"]
new_nameB = {
    "Unnamed: 17": "B9.a1",
    "Unnamed: 19": "B9.b1",
    "Unnamed: 21": "B9.c1",
    "Unnamed: 23": "B10.1",
    "Unnamed: 25": "B11.1",
    "Unnamed: 27": "B12.1"
}

columns_to_checkC = ["Unnamed: 29", "Unnamed: 30", "Unnamed: 31", "Unnamed: 32", "Unnamed: 33", "Unnamed: 34", "Unnamed: 35", "Unnamed: 36", "Unnamed: 37"]
new_nameC = {
    "Unnamed: 29": "C13",
    "Unnamed: 30": "C14",
    "Unnamed: 31": "C15",
    "Unnamed: 32": "C16",
    "Unnamed: 33": "C17",
    "Unnamed: 34": "C18",
    "Unnamed: 35": "C19",
    "Unnamed: 36": "C20",
    "Unnamed: 37": "C21"
}

columns_to_checkD = ['Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63']

new_nameD = {
    'Unnamed: 38': 'D22.a', 'Unnamed: 39': 'D22.b', 'Unnamed: 40': 'D22.c', 'Unnamed: 41': 'D22.d', 'Unnamed: 42': 'D22.e',
    'Unnamed: 43': 'D22.f', 'Unnamed: 44': 'D22.f.1', 'Unnamed: 45': 'D22.f.2', 'Unnamed: 46': 'D22.f.3', 'Unnamed: 47': 'D22.f.4',
    'Unnamed: 48': 'D23', 'Unnamed: 49': 'D24', 'Unnamed: 50': 'D25', 'Unnamed: 51': 'D26', 'Unnamed: 52': 'D27',
    'Unnamed: 53': 'D28', 'Unnamed: 54': 'D29', 'Unnamed: 55': 'D30', 'Unnamed: 56': 'D31', 'Unnamed: 57': 'D32',
    'Unnamed: 58': 'D33', 'Unnamed: 59': 'D33.a', 'Unnamed: 60': 'D33.b', 'Unnamed: 61': 'D33.c', 'Unnamed: 62': 'D34', 'Unnamed: 63': 'D35'
}

columncheckE = ["Unnamed: 64", "Unnamed: 65", "Unnamed: 67", "Unnamed: 69", "Unnamed: 71"]
new_nameE = {
    "Unnamed: 64": "E36",
    "Unnamed: 65": "E36.a.1",
    "Unnamed: 67": "E36.b.1",
    "Unnamed: 69": "E36.c.1",
    "Unnamed: 71": "E36.d.1"
}

columns_checkF = ["Unnamed: 73", "Unnamed: 74", "Unnamed: 75", "Unnamed: 76", "Unnamed: 77", "Unnamed: 78", "Unnamed: 79"]
new_nameF = {
    "Unnamed: 73": "F37",
    "Unnamed: 74": "F37.a",
    "Unnamed: 75": "F37.b",
    "Unnamed: 76": "F37.c",
    "Unnamed: 77": "F37.d",
    "Unnamed: 78": "F37.e",
    "Unnamed: 79": "F37.f"
}

# %% [markdown]
# # **I.Xây dựng hàm phân tích**

# %%
def analyze_and_plot(df, columns_to_check, new_column_names, group):
  symbols = ['①', '②', '③', '④', '⑤']
  symbol_labels = ['Hoàn toàn không đồng ý', 'Không đồng ý', 'Bình thường', 'Đồng ý', 'Rất đồng ý']
  # Create a dictionary to store the results
  results = {}

  # Calculate symbol counts for each column
  for column in columns_to_check:
      results[new_column_names[column]] = {symbol: df[column].str.contains(symbol, na=False).sum() for symbol in symbols}

  # Calculate "No Opinion" count for each column
      total_rows = len(df)
      symbols_count = sum(results[new_column_names[column]].values())
      results[new_column_names[column]]["Không có ý kiến"] = total_rows - 1 - symbols_count

  # Create a DataFrame from the results
  result_df = pd.DataFrame(results).T.fillna(0).astype(int)

  # Group by the first part of the column names (A1, A2, etc.) and sum
  grouped_results = result_df.groupby(result_df.index).sum()

  # Sau khi tính toán grouped_results:
  # Chuyển đổi bảng thành HTML với thẻ style để thêm đường kẻ
  table_html = tabulate(grouped_results, headers='keys', tablefmt='html')
  styled_table_html = f"""
  <style>
  table {{
      border-collapse: collapse; /* Gộp các đường viền của các ô */
      font-size: 16px; /* Kích thước chữ */
  }}
  table, th, td {{
      border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
  }}
  </style>
  {table_html}
  """


  # Thêm cột "Không có ý kiến" vào dữ liệu cho biểu đồ
  symbol_counts = grouped_results[symbols + ["Không có ý kiến"]].sum()  # Lấy tổng cho các cột symbol và "Không có ý kiến"

  # Tính phần trăm cho mỗi symbol (bao gồm "Không có ý kiến")
  symbol_percentages = (symbol_counts / symbol_counts.sum()) * 100

  # Tạo tiêu đề cho bảng
  table_title = f"<h3>Kết quả khảo sát nhóm {group}</h3>"

  # Hiển thị tiêu đề và bảng HTML trong Jupyter Notebook
  display(HTML(table_title + styled_table_html))

  # Thêm đường kẻ ngang
  display(HTML('<hr>'))  # <hr> là thẻ HTML tạo đường kẻ ngang

  # Vẽ biểu đồ tròn
  plt.figure(figsize=(8, 8))  # Điều chỉnh kích thước biểu đồ
  wedges, texts, autotexts = plt.pie(symbol_percentages, autopct='%1.1f%%', startangle=90)
  # wedges: Danh sách các wedge (miếng) của biểu đồ tròn
  # texts: Danh sách các đối tượng text (phần trăm) trên biểu đồ tròn
  # autotexts: Danh sách các đối tượng text (nhãn) trên biểu đồ tròn

  plt.title('Phần trăm mức độ đồng ý của nhóm' + group)
  plt.axis('equal')  # Đảm bảo biểu đồ tròn có hình tròn

  labels = []
  for i, (l, s) in enumerate(zip(symbol_counts.index, symbol_percentages)):
    if l in symbols:
      labels.append(f'{l} - {symbol_labels[symbols.index(l)]} ({s:.1f}%)')
    else:
      labels.append(f'{l} ({s:.1f}%)')  # For "Không có ý kiến"

  plt.legend(wedges, labels, title="Chú thích", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
  plt.show()

# %% [markdown]
# ## **II.PHÂN TÍCH**

# %% [markdown]
# # **PHÂN TÍCH NHÓM A**

# %%
analyze_and_plot(df, columns_to_checkA, new_nameA, ' A')
# Out:
# <h3>Kết quả khảo sát nhóm  A</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>    </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">   ④</th><th style="text-align: right;">   ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>A1.1</td><td style="text-align: right;">122</td><td style="text-align: right;"> 29</td><td style="text-align: right;">367</td><td style="text-align: right;">1202</td><td style="text-align: right;">1063</td><td style="text-align: right;">                0</td></tr>
# ...

# %% [markdown]
# # **PHÂN TÍCH NHÓM B**

# %%
analyze_and_plot(df, columns_to_checkB, new_nameB,' B')
# Out:
# <h3>Kết quả khảo sát nhóm  B</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>     </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">   ④</th><th style="text-align: right;">   ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>B10.1</td><td style="text-align: right;">105</td><td style="text-align: right;"> 46</td><td style="text-align: right;">510</td><td style="text-align: right;">1227</td><td style="text-align: right;"> 895</td><td style="text-align: right;">                0</td></tr>
# ...

# %% [markdown]
# # **PHÂN TÍCH NHÓM C**

# %%
analyze_and_plot(df, columns_to_checkC, new_nameC,' C')
# Out:
# <h3>Kết quả khảo sát nhóm  C</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>   </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">   ④</th><th style="text-align: right;">   ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>C13</td><td style="text-align: right;">101</td><td style="text-align: right;"> 55</td><td style="text-align: right;">421</td><td style="text-align: right;">1150</td><td style="text-align: right;">1056</td><td style="text-align: right;">                0</td></tr>
# ...

# %% [markdown]
# # **PHÂN TÍCH NHÓM D**

# %%
analyze_and_plot(df, columns_to_checkD, new_nameD,' D')
# Out:
# <h3>Kết quả khảo sát nhóm  D</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>       </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">   ④</th><th style="text-align: right;">  ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>D22.a  </td><td style="text-align: right;">129</td><td style="text-align: right;">172</td><td style="text-align: right;">698</td><td style="text-align: right;">1050</td><td style="text-align: right;">734</td><td style="text-align: right;">                0</td></tr>
# ...

# %% [markdown]
# # **PHÂN TÍCH NHÓM E**

# %%
analyze_and_plot(df, columncheckE, new_nameE,' E')
# Out:
# <h3>Kết quả khảo sát nhóm  E</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>       </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">   ④</th><th style="text-align: right;">  ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>E36    </td><td style="text-align: right;"> 95</td><td style="text-align: right;"> 54</td><td style="text-align: right;">651</td><td style="text-align: right;">1297</td><td style="text-align: right;">686</td><td style="text-align: right;">                0</td></tr>
# ...

# %% [markdown]
# # **PHÂN TÍCH NHÓM F**

# %%
analyze_and_plot(df=df, columns_to_check=columns_checkF, new_column_names=new_nameF,group=' F')
# Out:
# <h3>Kết quả khảo sát nhóm  F</h3>
#   <style>
#   table {
#       border-collapse: collapse; /* Gộp các đường viền của các ô */
#       font-size: 16px; /* Kích thước chữ */
#   }
#   table, th, td {
#       border: 1px solid black; /* Thêm đường viền cho bảng, tiêu đề và ô dữ liệu */
#   }
#   </style>
#   <table>
# <thead>
# <tr><th>     </th><th style="text-align: right;">  ①</th><th style="text-align: right;">  ②</th><th style="text-align: right;">  ③</th><th style="text-align: right;">  ④</th><th style="text-align: right;">  ⑤</th><th style="text-align: right;">  Không có ý kiến</th></tr>
# </thead>
# <tbody>
# <tr><td>F37  </td><td style="text-align: right;"> 80</td><td style="text-align: right;"> 39</td><td style="text-align: right;">452</td><td style="text-align: right;">920</td><td style="text-align: right;">545</td><td style="text-align: right;">              747</td></tr>
# ...
